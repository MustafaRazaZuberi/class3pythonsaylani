# %% [markdown]
# # Python Class 3

# %%
# We can concatenate string to string or integer to integer we cannto concatenate string to integer
first_name= "Mustafa"
last_name = "Raza"
full_name= first_name+ " " +last_name
print(full_name)
# Out:
# Mustafa Raza

# %%
print(100 + 500)
# Out:
# 600

# %%
country = "Pakistan"
country.upper()
# Out:
# 'PAKISTAN'

# %%
country
# Out:
# 'Pakistan'

# %%
country.lower()
# Out:
# 'pakistan'

# %%
country.count("a")
# Out:
# 2

# %%
email3.endswith("com")
# Out:
# True

# %%
email3 = input("Enter Your Personal Email: ")
email.find("gmail")
# Out:
# Enter Your Personal Email: mustafazuberi986@gmail.com
# 17

# %%
sentence = "This is Mustafa Here working  as a Data Scientist Specialist"
sentence.count("s")
# Out:
# 6

# %%
sentence.count("t")
# Out:
# 5

# %%
print(sentence)
# Out:
# This is Mustafa Here working  as a Data Scientist Specialist

# %%
sentence.count("a")
# Out:
# 7

# %%
sentence.endswith("Specialist")
# Out:
# True

# %%
sentence.endswith("t")
# Out:
# True

# %%
sentence.startswith("Mustafa")
# Out:
# False

# %%
sentence.isdigit()
# Out:
# False

# %%
number = 78
type(number)
# Out:
# int

# %%
number = "4324"
print(type(number))
# Out:
# <class 'str'>

# %%
number.isdigit()
# Out:
# True

# %%
email = " mustafazuberi986@gmail.com  "
len(email)
# Out:
# 28

# %%
email.lstrip()
# Out:
# 'mustafazuberi986@gmail.com '

# %%
email.rstrip()
# Out:
# ' mustafazuberi986@gmail.com'

# %%
email=email.lstrip()
email=email.rstrip()
email
# Out:
# 'mustafazuberi986@gmail.com'

# %%
email2 = "    smit@gmail.com    "
email2.strip()
# Out:
# 'smit@gmail.com'

# %%
email2
# Out:
# 'smit@gmail.com'

# %%
email2 = email2.strip()
email2
# Out:
# 'smit@gmail.com'

# %% [markdown]
# # Indexing of Strings

# %%
college = "Govt Superior Science College"
len(college)
# Out:
# 29

# %%
college[8]
# Out:
# 'e'

# %%
college[3:9]
# Out:
# 't Supe'

# %%
email2.find("i")
# Out:
# 2

# %%
email2.find("i",3)    #It means that Search starts form 3rd index
# Out:
# 8

# %% [markdown]
# # Rules for Variables

# %%
# Rules for naming variables:
# 1: Special characters are not allowed.
# 2: Can't start with numbers.
# 3: Spaces are not allowed.
# 4: Reserved words can't be use

# %% [markdown]
# # Number System

# %%
# binary number system (01)
# octal number system  (01234567)
# decimal number system (01234567)
# hexa decimal number system (0123456789)

# %%
0o45
# Out:
# 37

# %%
city = "karchi"
print(city)
# Out:
# karchi

# %%
# string is immutable
